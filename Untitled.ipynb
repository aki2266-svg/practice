# %%
import st
s=input()
print(st.f(s))
# Out:
# this is my c8
# this

# %%
import calc
s=input()
print(st.add())
# Out:
# 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-afa485d124f0> in <module>
#       1 import calc
#       2 s=input()
# ----> 3 print(st.add())
#
# AttributeError: module 'st' has no attribute 'add'

# %%
a=10
b=0
c=a/b
print(c)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-1-e82615c53705> in <module>
#       1 a=10
#       2 b=0
# ----> 3 c=a/b
#       4 print(c)
#
# ZeroDivisionError: division by zero

# %%
import math
print(math.exp(1000))
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-2-573e849b6c19> in <module>
#       1 import math
# ----> 2 print(math.exp(1000))
#
# OverflowError: math range error

# %%
a=5
if a>7:
    print(a)

# %%
a=[1,2,3]
print(a[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-f4963956c5c4> in <module>
#       1 a=[1,2,3]
# ----> 2 print(a[3])
#
# IndexError: list index out of range

# %%
a=5
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-a5f85553f491> in <module>
#       1 a=5
# ----> 2 print(x)
#
# NameError: name 'x' is not defined

# %%
a=5
if a>7
print(a)
# Out:
#   File "<ipython-input-10-f7a0fb035511>", line 2
#     if a>7
#           ^
# SyntaxError: invalid syntax

# %%
a={1:'a',2:'b'}
print(a[3])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-f61f3e91c9bc> in <module>
#       1 a={1:'a',2:'b'}
# ----> 2 print(a[3])
#
# KeyError: 3

# %%
1+'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-4650f3075b02> in <module>
# ----> 1 1+'a'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
a=int(input())
# Out:
# d
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-f7bced506b86> in <module>
# ----> 1 a=int(input())
#
# ValueError: invalid literal for int() with base 10: 'd'

# %%
import df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-fdfdad481824> in <module>
# ----> 1 import df
#
# ModuleNotFoundError: No module named 'df'

# %%
while True:
# Out:
#   File "<ipython-input-16-7abc45470d9b>", line 1
#     while True:
#                ^
# SyntaxError: unexpected EOF while parsing

# %%
while True:
    pass
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-b7133701d76c> in <module>
#       1 while True:
# ----> 2     pass
#
# KeyboardInterrupt:

# %%
f=open('c8.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-b5338ef4e88f> in <module>
# ----> 1 f=open('c8.txt')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c8.txt'

# %%
a=[1,2,3]
try:
    print(a[1])
    print(a[3])
except:
    print('An error occur')
# Out:
# 2
# An error occur

# %%
def f(a):
    if a<4:
        b=a/(a-3)
    print(b)
try:
    f(2)
except ZeroDivisionError:
    print('Zerodiv Error occur')
except NameError:
    print('Name not found')
# Out:
# -2.0

# %%
def f(a,b):
    try:
        c=(a+b)/(a-b)
    except ZeroDivisionError:
        print('a/bin 0')
    else:
        print(c)

# %%
f(2,3)
# Out:
# -5.0

# %%
f(3,3)
# Out:
# a/bin 0

# %%
try:
    k=2/0
except Exception as e:
    print(e)
else:
    print(k)
finally:
    print('This is finally')
# Out:
# division by zero
# This is finally

# %%
age=-1
if age<0:
    raise Exception('age')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-4-c4bbfc28ef6b> in <module>
#       1 age=-1
#       2 if age<0:
# ----> 3     raise Exception('age')
#
# Exception: age

# %%
class B(Exception):
    pass
l=5
if l<10:
    raise B('B too low')
# Out:
# ---------------------------------------------------------------------------
# B                                         Traceback (most recent call last)
# <ipython-input-6-108d58379d9f> in <module>
#       3 l=5
#       4 if l<10:
# ----> 5     raise B('B too low')
#
# B: B too low

# %%
def s(a):
    if (type(a)!=str):
        raise TypeError('a string')
    if(not a):
        raise ValueError('a null')
        a.strip()
        if(a==""):
            return True
        return False
try:
    a=' '
    print('is empty',s(a))
except ValueError as e:
    print('vError',e)
except TypeError as e:
    print('TError',e)
# Out:
# is empty None
