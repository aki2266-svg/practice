# %% [markdown]
# # MODULES AND DIRECTORY

# %%
import os
dir(os)
cwd=current working directory
mkdir=make direcctory
rmdir=remove directory
remove=file mate
pwd=present working directory
# Out:
# ['DirEntry',
#  'F_OK',
#  'MutableMapping',
#  'O_APPEND',
#  'O_BINARY',
#  'O_CREAT',
#  'O_EXCL',
#  'O_NOINHERIT',
#  'O_RANDOM',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SEQUENTIAL',
#  'O_SHORT_LIVED',
#  'O_TEMPORARY',
#  'O_TEXT',
#  'O_TRUNC',
#  'O_WRONLY',
#  'P_DETACH',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_OVERLAY',
#  'P_WAIT',
#  'PathLike',
#  'R_OK',
#  'SEEK_CUR',
#  'SEEK_END',
#  'SEEK_SET',
#  'TMP_MAX',
#  'W_OK',
#  'X_OK',
#  '_AddedDllDirectory',
#  '_Environ',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_check_methods',
#  '_execvpe',
#  '_exists',
#  '_exit',
#  '_fspath',
#  '_get_exports_list',
#  '_putenv',
#  '_unsetenv',
#  '_wrap_close',
#  'abc',
#  'abort',
#  'access',
#  'add_dll_directory',
#  'altsep',
#  'chdir',
#  'chmod',
#  'close',
#  'closerange',
#  'cpu_count',
#  'curdir',
#  'defpath',
#  'device_encoding',
#  'devnull',
#  'dup',
# ...

# %%
pwd
# Out:
# 'C:\\Users\\LJENG'

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\LJENG'

# %%
os.chdir('C:\\Users\\LJENG')

# %%
pwd
# Out:
# 'C:\\Users\\LJENG'

# %%
os.chdir('D:')

# %%
pwd
# Out:
# 'D:\\'

# %%
os.chdir('C:\\Users\\LJENG')

# %%
pwd
# Out:
# 'C:\\Users\\LJENG'

# %%
ls
# Out:
#  Volume in drive C is Win 10
#  Volume Serial Number is 3624-2097
#
#  Directory of C:\Users\LJENG
#
# 02-12-2025  10:25    <DIR>          .
# 02-12-2025  10:25    <DIR>          ..
# 02-12-2025  10:17    <DIR>          .ipynb_checkpoints
# 25-11-2025  08:46    <DIR>          .ipython
# 05-11-2025  09:22    <DIR>          .jupyter
# 09-06-2023  08:32    <DIR>          .vscode
# 14-10-2022  07:09    <DIR>          3D Objects
# 02-12-2025  10:17            11,426 ch6.ipynb
# 02-12-2025  10:25             5,621 ch7.ipynb
# 28-11-2025  13:05                48 compare1.txt
# 28-11-2025  13:07                48 compare2.txt
# 14-10-2022  07:09    <DIR>          Contacts
# 02-12-2025  09:15                49 copy.txt
# 02-12-2025  09:23                42 count.txt
# 13-11-2025  13:30    <DIR>          Desktop
# 15-11-2025  14:24    <DIR>          Documents
# 26-11-2025  12:06    <DIR>          Downloads
# 14-10-2022  07:09    <DIR>          Favorites
# ...

# %%
os.mkdir('C:\\Users\\LJENG\\new')

# %%
os.rmdir('C:\\Users\\LJENG\\new')

# %%
# %%writefile calc.py
def sum(a,b):
    print(a+b)
def sub(a,b):
    print(a-b)
def mult(a,b):
    print(a*b)
def div(a,b):
    print(a/b)
# Out:
# Writing calc.py

# %%
import calc
dir(calc)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'div',
#  'mult',
#  'sub',
#  'sum']

# %%
import calc
a=int(input("enter a:"))
b=int(input("enter b:"))
c=input("enter:")
if c=="sum":
    calc.sum(a,b)
elif c=="sub":
    calc.sub(a,b)
elif c=="mult":
    clac.mult(a,b)
elif c=="div":
    calc.div(a,b)
else:
    print("invalid")
# Out:
# enter a:2
# enter b:3
# enter:sum
# 5

# %%
# %%writefile mymodule.py
def sum(a,b):
    print(a+b)
def sub(a,b):
    print(a-b)
def mult(a,b):
    print(a*b)
def div(a,b):
    print(a/b)
# Out:
# Writing mymodule.py

# %%
import math
print(math.pi)
# Out:
# 3.141592653589793

# %%
import calc1
dir(calc1)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'floor']

# %%
import mymodule
mymodule.mult(5,3)
# Out:
# 15

# %%
from mymodule import mult
mult(5,3)
# Out:
# 15

# %%
from mymodule import sum,sub
sum(4,3)
mult(2,2)
# Out:
# 7
# 4

# %%
from calc import sum,sub
sum(4,3)
mult(2,2)
# Out:
# 7
# 4

# %%
from calc import sum,sub
sum(4,3)
mult(2,2)
# Out:
# 7
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8a2cff352992> in <module>
#       1 from calc import sum,sub
#       2 sum(4,3)
# ----> 3 mult(2,2)
#
# NameError: name 'mult' is not defined

# %%
cwd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e863a2ac204e> in <module>
# ----> 1 cwd
#
# NameError: name 'cwd' is not defined

# %%
getcwd()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-80c72379bb65> in <module>
# ----> 1 getcwd()
#
# NameError: name 'getcwd' is not defined

# %%
import os
getcwd()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4f8e5dc31067> in <module>
#       1 import os
# ----> 2 getcwd()
#
# NameError: name 'getcwd' is not defined

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\LJENG'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.vscode',
#  '3D Objects',
#  'AppData',
#  'Application Data',
#  'calc.py',
#  'calc1.py',
#  'ch6.ipynb',
#  'ch7.ipynb',
#  'compare1.txt',
#  'compare2.txt',
#  'Contacts',
#  'Cookies',
#  'copy.txt',
#  'count.txt',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'friends.txt',
#  'IntelGraphicsProfiles',
#  'Links',
#  'Local Settings',
#  'Music',
#  'My Documents',
#  'mymodule.py',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TM.blf',
#  'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'o1.txt',
#  'odd.txt',
#  'OneDrive',
#  'Oracle',
#  'output.txt',
#  'pager.txt',
#  'Pictures',
#  'PrintHood',
#  'Recent',
#  'replace.txt',
#  'Saved Games',
# ...

# %%
# %%writefile func.py
def lenght(s):
    return len(s)
def upper(s):
    return s.upper()
def lower(s):
    return s.lower()
def capital(s):
    return s.capitalize()
def isupper(s):
    return s.isupper()
def islower(s):
    return s.islower()
# Out:
# Writing func.py

# %%
import func
s=input("enter string:")
a=input("enter function to perform on it:")
if a=="lenght":
    print( func.lenght(s))
elif a=="upper":
    func.upper(s)
elif a=="lower":
    func.lower(s)
elif a=="capital":
    func.capital(s)
elif a=="isupper":
    func.isupper(s)
elif a=="islower":
    func.islower(s)
else:
    print("invalid")
# Out:
# enter string:akshat
# enter function to perform on it:lenght
# 6

# %%
import datetime
dir(datetime)
# Out:
# ['MAXYEAR',
#  'MINYEAR',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'date',
#  'datetime',
#  'datetime_CAPI',
#  'sys',
#  'time',
#  'timedelta',
#  'timezone',
#  'tzinfo']

# %%
from datetime import *
date.today()
# Out:
# datetime.date(2025, 12, 3)

# %%
d=date(2022,2,2)
print(d)
# Out:
# 2022-02-02

# %%
t=time(2,12,15)

# %%
print(t)
# Out:
# 02:12:15

# %%
print(datetime.now())
# Out:
# 2025-12-03 09:40:00.657290

# %% [markdown]
# # # package and subpackage

# %%
import os
os.mkdir('C:\\user\\LJENG\\pack1')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-95584d33136d> in <module>
#       1 import os
# ----> 2 os.mkdir('C:\\user\\LJENG\\pack1')
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\user\\LJENG\\pack1'

# %%
import os
os.mkdir('C:\\Users\\LJENG\\pack1')

# %%
os.cwd()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-e5f28aadf8d0> in <module>
# ----> 1 os.cwd()
#
# AttributeError: module 'os' has no attribute 'cwd'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\LJENG'

# %%
os.chdir('C:\\Users\\LJENG\\pack1')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\LJENG\\pack1'

# %%
# %%writefile modp.py
def fun():
    print("hello")
class hey:
    print("hey")
# Out:
# Writing modp.py

# %%
# %%writefile mod2.py
def bun():
    print("good")
# Out:
# Writing mod2.py

# %%
import pack1 as m
dir(m)
# Out:
# ['__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__']
